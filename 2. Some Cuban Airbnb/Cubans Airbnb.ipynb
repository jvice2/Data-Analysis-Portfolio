# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
pd.set_option('display.max_rows', None)  
pd.set_option('display.max_columns', None)

# %%
# We are going to use a web page that i saved and select the desired table
url = 'D:\Downloads\Cuba Hotel Search Results.html'

with open(url, encoding='utf-8') as file:
    reader = file.read()
    soup = BeautifulSoup(reader, 'html.parser')

tables = soup.find_all(class_='uitk-spacing uitk-spacing-margin-blockstart-three') # This is the table i put in my git hub repo

# %%
# After a manual search we find the labels we need to create a table with key info about the houses
rows = []
for table in tables:
    name = table.find('h3', class_="uitk-heading uitk-heading-5 overflow-wrap uitk-layout-grid-item uitk-layout-grid-item-has-row-start")
    if name is None:
        continue
    location = table.find('div', class_="uitk-text uitk-text-spacing-half truncate-lines-2 uitk-type-300 uitk-text-default-theme")
    breakfast = table.find('div', class_="uitk-text truncate-lines-2 uitk-type-200 uitk-text-default-theme")
    if breakfast is not None:
        breakfast = 'yes'
    else: breakfast = 'no'
    rating = table.find('span', class_="uitk-badge-base-text")
    if rating is None:
      continue
    reviews = table.find('span', class_="uitk-text uitk-type-200 uitk-type-regular uitk-text-default-theme")
    if reviews is None:
        reviews = 0
    else: reviews = reviews.text
    current_price = table.find('div', class_="uitk-text uitk-type-500 uitk-type-medium uitk-text-emphasis-theme")
    old_price = table.find('div', class_="uitk-text uitk-type-300 uitk-text-default-theme")
    if old_price is None:
        old_price = current_price

    row = [name.text, location.text, breakfast, rating.text, reviews, old_price.text, current_price.text]
    rows.append(row)

columns = ['Name', 'Location', 'Breakfast', 'Rating', 'Reviews', 'Old_Price(USD)', 'Current_Price(USD)']
airbnb_table = pd.DataFrame(rows, columns=columns)
airbnb_table['Current_Price(USD)'] = airbnb_table['Current_Price(USD)'].apply(lambda x: x[1:]).astype('int64')
airbnb_table['Old_Price(USD)'] = airbnb_table['Old_Price(USD)'].apply(lambda x: x[1:]).astype('int64')
airbnb_table['Reviews'] = airbnb_table['Reviews'].apply(lambda x: x[:-8]).astype('int64')
airbnb_table
# Out:
#                                              Name              Location  \
# 0                      Art Studio Habana Vieja 55                Havana
# 1                                        Alhabana                Havana
# 2                        Vapor 156 Boutique Hotel                Havana
# 3                     CasavanaCuba Boutique Hotel                Havana
# 4                            Boutique Casa Italia                Havana
# 5                            Napper by Rottenberg                Havana
# 6                        Alahabana Boutique Hotel                Havana
# 7                      La Alameda Boutique Hotel                 Havana
# 8                                 Casa 2 Sonrisas               Viñales
# 9                                  Casa Mi Tierra                Havana
# 10                              La Reserva Vedado                Havana
# 11                        Hostal Doña Amalia Cuba                Havana
# 12                        Aimara's Hotel Boutique                Havana
# 13                        Mayari Havana Apartment                Havana
# 14                                 Villa Cuba BNB                Havana
# 15                                        La Maye                Havana
# 16                         Residencia Santa Clara                Havana
# 17                            Lola Trinidad Hotel              Trinidad
# 18                    Hostal La Maestranza Habana                Havana
# 19                                  Casa Factoria                Havana
# 20                   Quinta & Ocho Hotel Boutique                Havana
# 21                       El Candil Boutique Hotel                Havana
# 22                          Claxon Hotel Boutique                Havana
# 23                     Casa Colonial Torrado 1830              Trinidad
# 24                        Hostal Balcones Muralla                Havana
# 25                          Hostal del Buen Viaje                Havana
# 26                    Casa Miriam Hostal Colonial                Havana
# 27                                    Loft Habana                Havana
# 28                 Blanc Blue 1924 Boutique Hotel                Havana
# 29                                      Joe David                Havana
# 30                                La Villa Teresa                Havana
# 31                  Villa Paradiso Marilin y Yuri               Viñales
# 32                       Paseo 206 Boutique Hotel                Havana
# 33                                      VIP Morro                Havana
# 34                                Hotel Ramiro's                 Havana
# 35                                   Casa Salatti                Havana
# 36                 Apodaca 12 Hotel Boutique Cuba              Camaguey
# 37                              Hostal MiraHabana                Havana
# 38                              ARTeHotel Calle 2                Havana
# 39                                   Hostal Selfa  Sleeps 3, 1 bathroom
# 40                                EL81 Guesthouse                Havana
# 41                                    La Española                Havana
# 42                                     Isac David                Havana
# 43                     Hotel Palacio Barón Balbín            Cienfuegos
# 44                Estancia Bohemia Boutique Hotel                Havana
# 45                                  Consulado 106                Havana
# 46                                     Casa Oscar               Holguín
# 47                            Art Boutique Havana                Havana
# 48                Casa Colonial Lalita Cienfuegos            Cienfuegos
# 49                                    Casa Carmen                Havana
# 50                                   Las Palmeras               Baracoa
# 51                          Hostal Puerto Casilda              Trinidad
# 52                                  Hostal Merced                Havana
# 53                           Casa De Las Banderas            Cienfuegos
# 54                          Hotel Boutique Balear                Havana
# 55                          Hostal Habana Tu & Yo                Havana
# 56                            Villa Pupi y Emilio      Entire apartment
# 57                            El Almendron Rosado                Havana
# 58                        Elegancia Suites Habana                Havana
# 59                                Villa Los Reyes               Viñales
# 60                   Hostal Colonial Casa de Luca                Havana
# 61                               Casa Carlos Rico                Havana
# 62  Wilber House 4 Hours Free Horse Tour Included               Viñales
# 63                                   Havana Dream                Havana
# 64                            Casa Lucilo y Nirma               Viñales
# 65                           Hostal MIMI'S PALACE              Cárdenas
# 66                        Apartamento en Aguacate                Havana
# 67                          Ocean Breeze & Suites                Havana
# 68                          Casa Nochea y Familia              Trinidad
# 69                                 San Lazaro 115                Havana
# 70                          Hostal Los Villanueva                Havana
# 71      Casa Colonial Abogados Leonardo y Angela                 Havana
# 72                          Private Apartment Ysa                Havana
# 73                                   La Siguaraya                Havana
# 74           Casa Colonial Marvel - Habana Center                Havana
# 75                              Casa Brava Havana                Havana
# 76                  Casa Colonial Yadilis  y Yoel                Havana
# 77                           Apartamento San Juan                Havana
# 78                                Casa Los Rubios               Viñales
# 79                    La Distancia Hotel Boutique                Havana
# 80                        Casa David y Lidia Diaz                Havana
# 81                           Hotel Chile Habanero                Havana
# 82                    Doña Isabel - La Giraldilla                Havana
# 83                            Casa Colonial Mario                Havana
# 84                                      Casa Lili                Havana
# 85                                SAN IGNACIO 659                Havana
# 86                                Hostal Casa Mia              Trinidad
# 87                                  Casa El Porry               Viñales
# 88          Hostal Doña Cristina de Anita y Manel              Trinidad
# 89                        Residencia Albero Dulce                Havana
# 90                                 Hostal Marilin                Havana
# 91                        Casa Maura Habana Vieja                Havana
# 92                           Familia Cienfueguera            Cienfuegos
# 93                    Jesus Maria 7 Casa Boutique                Havana
# 94                                Mansion Alameda              Trinidad
# 95                                   REV Boutique                Havana
# 96                    Villa Carmita Casa Colonial                Havana
# 97                                    Casa MiCuba              Trinidad
# 98                               Casa Pedro-María                Havana
#
#    Breakfast Rating  Reviews  Old_Price(USD)  Current_Price(USD)
# 0         no    8.4      387              80                  44
# 1        yes    9.6      548              68                  61
# 2         no    9.4      299             120                  90
# 3         no    9.4      736              79                  79
# 4        yes    9.8       24             217                 195
# 5        yes    9.6      113             162                 105
# 6         no    9.6      271             133                  47
# 7        yes     10       55             131                 117
# 8         no     10      134              38                  30
# 9        yes    9.6      224              39                  35
# 10       yes    9.4       79             293                 263
# 11        no    9.8      237              70                  49
# 12        no    9.6      162              39                  35
# 13        no    9.8       62             156                 141
# 14       yes    9.8       94              77                  54
# 15        no    9.4      117              35                  25
# 16       yes    9.8      138             151                 151
# 17       yes     10       39              60                  48
# 18        no    9.2       96              63                  50
# 19       yes    9.6      146              78                  55
# 20       yes    9.4      196             195                 117
# 21       yes    9.8      233             140                 140
# 22       yes    9.8       29             197                 158
# 23       yes    9.2      120              68                  54
# 24       yes    9.6      246              98                  88
# 25       yes    9.4       99             160                 144
# 26        no    9.4       49              33                  23
# 27        no    8.4      291             245                 196
# 28        no    9.2      270              40                  28
# 29        no    9.2       49              18                  16
# 30       yes    9.4      173              60                  54
# 31       yes    9.6       94              21                  15
# 32       yes    9.6      147             249                 174
# 33        no    9.2       19             188                 131
# 34       yes     10        3              70                  70
# 35        no    9.2       38              31                  22
# 36        no    9.8       52              90                  81
# 37       yes    9.8      157              26                  23
# 38        no    9.6       90             146                 131
# 39        no    9.6       96              46                  41
# 40        no     10       97              56                  51
# 41        no    8.8      130              30                  21
# 42        no    9.0       68              18                  16
# 43       yes    9.2      108              83                  58
# 44       yes    9.8        9             449                 314
# 45        no    9.8        8              33                  33
# 46        no    9.6       47              36                  26
# 47        no    9.4      250             135                  95
# 48        no    9.4      137              26                  18
# 49       yes    9.4      172              26                  18
# 50        no    9.8       15              24                  22
# 51       yes    9.8       77              47                  42
# 52        no    9.4       50              96                  77
# 53        no    9.8       49              19                  17
# 54        no    8.8       37              77                  62
# 55        no    9.0      135              48                  38
# 56       yes     10       12               8                   7
# 57        no    9.6      130              81                  57
# 58       yes    9.6      168             117                  67
# 59        no     10       11              36                  33
# 60       yes    9.6      145              40                  36
# 61        no    9.2       61              26                  18
# 62       yes     10       84              33                  23
# 63        no    9.0       87              83                  75
# 64       yes    9.2       84              36                  32
# 65        no    9.6      103              30                  27
# 66        no     10        9              36                  33
# 67        no    9.4       11             114                  80
# 68        no    9.4       59              19                  15
# 69        no    9.4      165              61                  55
# 70        no    9.6      112              57                  52
# 71        no    9.8       83              42                  38
# 72        no    9.4       13              55                  50
# 73       yes    8.6       62              79                  55
# 74        no    9.4       40              54                  21
# 75        no     10        4             150                 135
# 76        no     10       40              46                  37
# 77        no     10        6              36                  33
# 78        no     10       65              19                  15
# 79       yes    9.8        9             201                 181
# 80        no    9.4       95              17                  17
# 81       yes    8.4      155              78                  55
# 82       yes    9.4      145              52                  42
# 83        no     10        5              45                  45
# 84       yes     10        5             110                  99
# 85       yes    9.8       54              95                  86
# 86        no    9.6       84              31                  31
# 87       yes    9.6       68              40                  40
# 88        no    9.8      119              33                  27
# 89        no    9.4       72              63                  50
# 90        no    9.4       34              50                  35
# 91        no    9.8       65              42                  33
# 92        no    9.4       42              16                  14
# 93       yes     10       82             115                  80
# 94       yes     10        2             234                 211
# 95        no    9.2      107              92                  74
# 96        no    9.8       78              76                  62
# 97        no     10       19              51                  51
# 98        no    9.0      118              79                  71

# %%
airbnb_table.info() # there is no missing value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                99 non-null     object
#  1   Location            99 non-null     object
#  2   Breakfast           99 non-null     object
#  3   Rating              99 non-null     object
#  4   Reviews             99 non-null     int64
#  5   Old_Price(USD)      99 non-null     int64
#  6   Current_Price(USD)  99 non-null     int64
# dtypes: int64(3), object(4)
# memory usage: 5.5+ KB

# %%
# At first glance we notice some mistakes (name in row 62 and location value in rows 39 and 56) and manually fix them)
airbnb_table.loc[airbnb_table['Location']=='Entire apartment', 'Location'] = 'Viñales'
airbnb_table.loc[airbnb_table['Location']=='Sleeps\xa03, 1\xa0bathroom', 'Location'] = 'Cárdenas'
airbnb_table.loc[airbnb_table['Name']=='Wilber House 4 Hours Free Horse Tour Included', 'Name'] = 'Wilber House'
airbnb_table
# Out:
#                                          Name    Location Breakfast Rating  \
# 0                  Art Studio Habana Vieja 55      Havana        no    8.4
# 1                                    Alhabana      Havana       yes    9.6
# 2                    Vapor 156 Boutique Hotel      Havana        no    9.4
# 3                 CasavanaCuba Boutique Hotel      Havana        no    9.4
# 4                        Boutique Casa Italia      Havana       yes    9.8
# 5                        Napper by Rottenberg      Havana       yes    9.6
# 6                    Alahabana Boutique Hotel      Havana        no    9.6
# 7                  La Alameda Boutique Hotel       Havana       yes     10
# 8                             Casa 2 Sonrisas     Viñales        no     10
# 9                              Casa Mi Tierra      Havana       yes    9.6
# 10                          La Reserva Vedado      Havana       yes    9.4
# 11                    Hostal Doña Amalia Cuba      Havana        no    9.8
# 12                    Aimara's Hotel Boutique      Havana        no    9.6
# 13                    Mayari Havana Apartment      Havana        no    9.8
# 14                             Villa Cuba BNB      Havana       yes    9.8
# 15                                    La Maye      Havana        no    9.4
# 16                     Residencia Santa Clara      Havana       yes    9.8
# 17                        Lola Trinidad Hotel    Trinidad       yes     10
# 18                Hostal La Maestranza Habana      Havana        no    9.2
# 19                              Casa Factoria      Havana       yes    9.6
# 20               Quinta & Ocho Hotel Boutique      Havana       yes    9.4
# 21                   El Candil Boutique Hotel      Havana       yes    9.8
# 22                      Claxon Hotel Boutique      Havana       yes    9.8
# 23                 Casa Colonial Torrado 1830    Trinidad       yes    9.2
# 24                    Hostal Balcones Muralla      Havana       yes    9.6
# 25                      Hostal del Buen Viaje      Havana       yes    9.4
# 26                Casa Miriam Hostal Colonial      Havana        no    9.4
# 27                                Loft Habana      Havana        no    8.4
# 28             Blanc Blue 1924 Boutique Hotel      Havana        no    9.2
# 29                                  Joe David      Havana        no    9.2
# 30                            La Villa Teresa      Havana       yes    9.4
# 31              Villa Paradiso Marilin y Yuri     Viñales       yes    9.6
# 32                   Paseo 206 Boutique Hotel      Havana       yes    9.6
# 33                                  VIP Morro      Havana        no    9.2
# 34                            Hotel Ramiro's       Havana       yes     10
# 35                               Casa Salatti      Havana        no    9.2
# 36             Apodaca 12 Hotel Boutique Cuba    Camaguey        no    9.8
# 37                          Hostal MiraHabana      Havana       yes    9.8
# 38                          ARTeHotel Calle 2      Havana        no    9.6
# 39                               Hostal Selfa    Cárdenas        no    9.6
# 40                            EL81 Guesthouse      Havana        no     10
# 41                                La Española      Havana        no    8.8
# 42                                 Isac David      Havana        no    9.0
# 43                 Hotel Palacio Barón Balbín  Cienfuegos       yes    9.2
# 44            Estancia Bohemia Boutique Hotel      Havana       yes    9.8
# 45                              Consulado 106      Havana        no    9.8
# 46                                 Casa Oscar     Holguín        no    9.6
# 47                        Art Boutique Havana      Havana        no    9.4
# 48            Casa Colonial Lalita Cienfuegos  Cienfuegos        no    9.4
# 49                                Casa Carmen      Havana       yes    9.4
# 50                               Las Palmeras     Baracoa        no    9.8
# 51                      Hostal Puerto Casilda    Trinidad       yes    9.8
# 52                              Hostal Merced      Havana        no    9.4
# 53                       Casa De Las Banderas  Cienfuegos        no    9.8
# 54                      Hotel Boutique Balear      Havana        no    8.8
# 55                      Hostal Habana Tu & Yo      Havana        no    9.0
# 56                        Villa Pupi y Emilio     Viñales       yes     10
# 57                        El Almendron Rosado      Havana        no    9.6
# 58                    Elegancia Suites Habana      Havana       yes    9.6
# 59                            Villa Los Reyes     Viñales        no     10
# 60               Hostal Colonial Casa de Luca      Havana       yes    9.6
# 61                           Casa Carlos Rico      Havana        no    9.2
# 62                               Wilber House     Viñales       yes     10
# 63                               Havana Dream      Havana        no    9.0
# 64                        Casa Lucilo y Nirma     Viñales       yes    9.2
# 65                       Hostal MIMI'S PALACE    Cárdenas        no    9.6
# 66                    Apartamento en Aguacate      Havana        no     10
# 67                      Ocean Breeze & Suites      Havana        no    9.4
# 68                      Casa Nochea y Familia    Trinidad        no    9.4
# 69                             San Lazaro 115      Havana        no    9.4
# 70                      Hostal Los Villanueva      Havana        no    9.6
# 71  Casa Colonial Abogados Leonardo y Angela       Havana        no    9.8
# 72                      Private Apartment Ysa      Havana        no    9.4
# 73                               La Siguaraya      Havana       yes    8.6
# 74       Casa Colonial Marvel - Habana Center      Havana        no    9.4
# 75                          Casa Brava Havana      Havana        no     10
# 76              Casa Colonial Yadilis  y Yoel      Havana        no     10
# 77                       Apartamento San Juan      Havana        no     10
# 78                            Casa Los Rubios     Viñales        no     10
# 79                La Distancia Hotel Boutique      Havana       yes    9.8
# 80                    Casa David y Lidia Diaz      Havana        no    9.4
# 81                       Hotel Chile Habanero      Havana       yes    8.4
# 82                Doña Isabel - La Giraldilla      Havana       yes    9.4
# 83                        Casa Colonial Mario      Havana        no     10
# 84                                  Casa Lili      Havana       yes     10
# 85                            SAN IGNACIO 659      Havana       yes    9.8
# 86                            Hostal Casa Mia    Trinidad        no    9.6
# 87                              Casa El Porry     Viñales       yes    9.6
# 88      Hostal Doña Cristina de Anita y Manel    Trinidad        no    9.8
# 89                    Residencia Albero Dulce      Havana        no    9.4
# 90                             Hostal Marilin      Havana        no    9.4
# 91                    Casa Maura Habana Vieja      Havana        no    9.8
# 92                       Familia Cienfueguera  Cienfuegos        no    9.4
# 93                Jesus Maria 7 Casa Boutique      Havana       yes     10
# 94                            Mansion Alameda    Trinidad       yes     10
# 95                               REV Boutique      Havana        no    9.2
# 96                Villa Carmita Casa Colonial      Havana        no    9.8
# 97                                Casa MiCuba    Trinidad        no     10
# 98                           Casa Pedro-María      Havana        no    9.0
#
#     Reviews  Old_Price(USD)  Current_Price(USD)
# 0       387              80                  44
# 1       548              68                  61
# 2       299             120                  90
# 3       736              79                  79
# 4        24             217                 195
# 5       113             162                 105
# 6       271             133                  47
# 7        55             131                 117
# 8       134              38                  30
# 9       224              39                  35
# 10       79             293                 263
# 11      237              70                  49
# 12      162              39                  35
# 13       62             156                 141
# 14       94              77                  54
# 15      117              35                  25
# 16      138             151                 151
# 17       39              60                  48
# 18       96              63                  50
# 19      146              78                  55
# 20      196             195                 117
# 21      233             140                 140
# 22       29             197                 158
# 23      120              68                  54
# 24      246              98                  88
# 25       99             160                 144
# 26       49              33                  23
# 27      291             245                 196
# 28      270              40                  28
# 29       49              18                  16
# 30      173              60                  54
# 31       94              21                  15
# 32      147             249                 174
# 33       19             188                 131
# 34        3              70                  70
# 35       38              31                  22
# 36       52              90                  81
# 37      157              26                  23
# 38       90             146                 131
# 39       96              46                  41
# 40       97              56                  51
# 41      130              30                  21
# 42       68              18                  16
# 43      108              83                  58
# 44        9             449                 314
# 45        8              33                  33
# 46       47              36                  26
# 47      250             135                  95
# 48      137              26                  18
# 49      172              26                  18
# 50       15              24                  22
# 51       77              47                  42
# 52       50              96                  77
# 53       49              19                  17
# 54       37              77                  62
# 55      135              48                  38
# 56       12               8                   7
# 57      130              81                  57
# 58      168             117                  67
# 59       11              36                  33
# 60      145              40                  36
# 61       61              26                  18
# 62       84              33                  23
# 63       87              83                  75
# 64       84              36                  32
# 65      103              30                  27
# 66        9              36                  33
# 67       11             114                  80
# 68       59              19                  15
# 69      165              61                  55
# 70      112              57                  52
# 71       83              42                  38
# 72       13              55                  50
# 73       62              79                  55
# 74       40              54                  21
# 75        4             150                 135
# 76       40              46                  37
# 77        6              36                  33
# 78       65              19                  15
# 79        9             201                 181
# 80       95              17                  17
# 81      155              78                  55
# 82      145              52                  42
# 83        5              45                  45
# 84        5             110                  99
# 85       54              95                  86
# 86       84              31                  31
# 87       68              40                  40
# 88      119              33                  27
# 89       72              63                  50
# 90       34              50                  35
# 91       65              42                  33
# 92       42              16                  14
# 93       82             115                  80
# 94        2             234                 211
# 95      107              92                  74
# 96       78              76                  62
# 97       19              51                  51
# 98      118              79                  71

# %%
# Now we add a province column for future analysis
province = {'Havana': 'Havana', 'Viñales': 'Pinar del Rio', 'Trinidad': 'Sancti Spiritus', 'Camaguey': 'Camaguey',
            'Cárdenas': 'Matanzas', 'Cienfuegos': 'Cienfuegos', 'Holguín': 'Holguín', 'Baracoa': 'Guantanamo'}
airbnb_table['Province'] = airbnb_table['Location'].map(province)
airbnb_table
# Out:
#                                          Name    Location Breakfast Rating  \
# 0                  Art Studio Habana Vieja 55      Havana        no    8.4
# 1                                    Alhabana      Havana       yes    9.6
# 2                    Vapor 156 Boutique Hotel      Havana        no    9.4
# 3                 CasavanaCuba Boutique Hotel      Havana        no    9.4
# 4                        Boutique Casa Italia      Havana       yes    9.8
# 5                        Napper by Rottenberg      Havana       yes    9.6
# 6                    Alahabana Boutique Hotel      Havana        no    9.6
# 7                  La Alameda Boutique Hotel       Havana       yes     10
# 8                             Casa 2 Sonrisas     Viñales        no     10
# 9                              Casa Mi Tierra      Havana       yes    9.6
# 10                          La Reserva Vedado      Havana       yes    9.4
# 11                    Hostal Doña Amalia Cuba      Havana        no    9.8
# 12                    Aimara's Hotel Boutique      Havana        no    9.6
# 13                    Mayari Havana Apartment      Havana        no    9.8
# 14                             Villa Cuba BNB      Havana       yes    9.8
# 15                                    La Maye      Havana        no    9.4
# 16                     Residencia Santa Clara      Havana       yes    9.8
# 17                        Lola Trinidad Hotel    Trinidad       yes     10
# 18                Hostal La Maestranza Habana      Havana        no    9.2
# 19                              Casa Factoria      Havana       yes    9.6
# 20               Quinta & Ocho Hotel Boutique      Havana       yes    9.4
# 21                   El Candil Boutique Hotel      Havana       yes    9.8
# 22                      Claxon Hotel Boutique      Havana       yes    9.8
# 23                 Casa Colonial Torrado 1830    Trinidad       yes    9.2
# 24                    Hostal Balcones Muralla      Havana       yes    9.6
# 25                      Hostal del Buen Viaje      Havana       yes    9.4
# 26                Casa Miriam Hostal Colonial      Havana        no    9.4
# 27                                Loft Habana      Havana        no    8.4
# 28             Blanc Blue 1924 Boutique Hotel      Havana        no    9.2
# 29                                  Joe David      Havana        no    9.2
# 30                            La Villa Teresa      Havana       yes    9.4
# 31              Villa Paradiso Marilin y Yuri     Viñales       yes    9.6
# 32                   Paseo 206 Boutique Hotel      Havana       yes    9.6
# 33                                  VIP Morro      Havana        no    9.2
# 34                            Hotel Ramiro's       Havana       yes     10
# 35                               Casa Salatti      Havana        no    9.2
# 36             Apodaca 12 Hotel Boutique Cuba    Camaguey        no    9.8
# 37                          Hostal MiraHabana      Havana       yes    9.8
# 38                          ARTeHotel Calle 2      Havana        no    9.6
# 39                               Hostal Selfa    Cárdenas        no    9.6
# 40                            EL81 Guesthouse      Havana        no     10
# 41                                La Española      Havana        no    8.8
# 42                                 Isac David      Havana        no    9.0
# 43                 Hotel Palacio Barón Balbín  Cienfuegos       yes    9.2
# 44            Estancia Bohemia Boutique Hotel      Havana       yes    9.8
# 45                              Consulado 106      Havana        no    9.8
# 46                                 Casa Oscar     Holguín        no    9.6
# 47                        Art Boutique Havana      Havana        no    9.4
# 48            Casa Colonial Lalita Cienfuegos  Cienfuegos        no    9.4
# 49                                Casa Carmen      Havana       yes    9.4
# 50                               Las Palmeras     Baracoa        no    9.8
# 51                      Hostal Puerto Casilda    Trinidad       yes    9.8
# 52                              Hostal Merced      Havana        no    9.4
# 53                       Casa De Las Banderas  Cienfuegos        no    9.8
# 54                      Hotel Boutique Balear      Havana        no    8.8
# 55                      Hostal Habana Tu & Yo      Havana        no    9.0
# 56                        Villa Pupi y Emilio     Viñales       yes     10
# 57                        El Almendron Rosado      Havana        no    9.6
# 58                    Elegancia Suites Habana      Havana       yes    9.6
# 59                            Villa Los Reyes     Viñales        no     10
# 60               Hostal Colonial Casa de Luca      Havana       yes    9.6
# 61                           Casa Carlos Rico      Havana        no    9.2
# 62                               Wilber House     Viñales       yes     10
# 63                               Havana Dream      Havana        no    9.0
# 64                        Casa Lucilo y Nirma     Viñales       yes    9.2
# 65                       Hostal MIMI'S PALACE    Cárdenas        no    9.6
# 66                    Apartamento en Aguacate      Havana        no     10
# 67                      Ocean Breeze & Suites      Havana        no    9.4
# 68                      Casa Nochea y Familia    Trinidad        no    9.4
# 69                             San Lazaro 115      Havana        no    9.4
# 70                      Hostal Los Villanueva      Havana        no    9.6
# 71  Casa Colonial Abogados Leonardo y Angela       Havana        no    9.8
# 72                      Private Apartment Ysa      Havana        no    9.4
# 73                               La Siguaraya      Havana       yes    8.6
# 74       Casa Colonial Marvel - Habana Center      Havana        no    9.4
# 75                          Casa Brava Havana      Havana        no     10
# 76              Casa Colonial Yadilis  y Yoel      Havana        no     10
# 77                       Apartamento San Juan      Havana        no     10
# 78                            Casa Los Rubios     Viñales        no     10
# 79                La Distancia Hotel Boutique      Havana       yes    9.8
# 80                    Casa David y Lidia Diaz      Havana        no    9.4
# 81                       Hotel Chile Habanero      Havana       yes    8.4
# 82                Doña Isabel - La Giraldilla      Havana       yes    9.4
# 83                        Casa Colonial Mario      Havana        no     10
# 84                                  Casa Lili      Havana       yes     10
# 85                            SAN IGNACIO 659      Havana       yes    9.8
# 86                            Hostal Casa Mia    Trinidad        no    9.6
# 87                              Casa El Porry     Viñales       yes    9.6
# 88      Hostal Doña Cristina de Anita y Manel    Trinidad        no    9.8
# 89                    Residencia Albero Dulce      Havana        no    9.4
# 90                             Hostal Marilin      Havana        no    9.4
# 91                    Casa Maura Habana Vieja      Havana        no    9.8
# 92                       Familia Cienfueguera  Cienfuegos        no    9.4
# 93                Jesus Maria 7 Casa Boutique      Havana       yes     10
# 94                            Mansion Alameda    Trinidad       yes     10
# 95                               REV Boutique      Havana        no    9.2
# 96                Villa Carmita Casa Colonial      Havana        no    9.8
# 97                                Casa MiCuba    Trinidad        no     10
# 98                           Casa Pedro-María      Havana        no    9.0
#
#     Reviews  Old_Price(USD)  Current_Price(USD)         Province
# 0       387              80                  44           Havana
# 1       548              68                  61           Havana
# 2       299             120                  90           Havana
# 3       736              79                  79           Havana
# 4        24             217                 195           Havana
# 5       113             162                 105           Havana
# 6       271             133                  47           Havana
# 7        55             131                 117           Havana
# 8       134              38                  30    Pinar del Rio
# 9       224              39                  35           Havana
# 10       79             293                 263           Havana
# 11      237              70                  49           Havana
# 12      162              39                  35           Havana
# 13       62             156                 141           Havana
# 14       94              77                  54           Havana
# 15      117              35                  25           Havana
# 16      138             151                 151           Havana
# 17       39              60                  48  Sancti Spiritus
# 18       96              63                  50           Havana
# 19      146              78                  55           Havana
# 20      196             195                 117           Havana
# 21      233             140                 140           Havana
# 22       29             197                 158           Havana
# 23      120              68                  54  Sancti Spiritus
# 24      246              98                  88           Havana
# 25       99             160                 144           Havana
# 26       49              33                  23           Havana
# 27      291             245                 196           Havana
# 28      270              40                  28           Havana
# 29       49              18                  16           Havana
# 30      173              60                  54           Havana
# 31       94              21                  15    Pinar del Rio
# 32      147             249                 174           Havana
# 33       19             188                 131           Havana
# 34        3              70                  70           Havana
# 35       38              31                  22           Havana
# 36       52              90                  81         Camaguey
# 37      157              26                  23           Havana
# 38       90             146                 131           Havana
# 39       96              46                  41         Matanzas
# 40       97              56                  51           Havana
# 41      130              30                  21           Havana
# 42       68              18                  16           Havana
# 43      108              83                  58       Cienfuegos
# 44        9             449                 314           Havana
# 45        8              33                  33           Havana
# 46       47              36                  26          Holguín
# 47      250             135                  95           Havana
# 48      137              26                  18       Cienfuegos
# 49      172              26                  18           Havana
# 50       15              24                  22       Guantanamo
# 51       77              47                  42  Sancti Spiritus
# 52       50              96                  77           Havana
# 53       49              19                  17       Cienfuegos
# 54       37              77                  62           Havana
# 55      135              48                  38           Havana
# 56       12               8                   7    Pinar del Rio
# 57      130              81                  57           Havana
# 58      168             117                  67           Havana
# 59       11              36                  33    Pinar del Rio
# 60      145              40                  36           Havana
# 61       61              26                  18           Havana
# 62       84              33                  23    Pinar del Rio
# 63       87              83                  75           Havana
# 64       84              36                  32    Pinar del Rio
# 65      103              30                  27         Matanzas
# 66        9              36                  33           Havana
# 67       11             114                  80           Havana
# 68       59              19                  15  Sancti Spiritus
# 69      165              61                  55           Havana
# 70      112              57                  52           Havana
# 71       83              42                  38           Havana
# 72       13              55                  50           Havana
# 73       62              79                  55           Havana
# 74       40              54                  21           Havana
# 75        4             150                 135           Havana
# 76       40              46                  37           Havana
# 77        6              36                  33           Havana
# 78       65              19                  15    Pinar del Rio
# 79        9             201                 181           Havana
# 80       95              17                  17           Havana
# 81      155              78                  55           Havana
# 82      145              52                  42           Havana
# 83        5              45                  45           Havana
# 84        5             110                  99           Havana
# 85       54              95                  86           Havana
# 86       84              31                  31  Sancti Spiritus
# 87       68              40                  40    Pinar del Rio
# 88      119              33                  27  Sancti Spiritus
# 89       72              63                  50           Havana
# 90       34              50                  35           Havana
# 91       65              42                  33           Havana
# 92       42              16                  14       Cienfuegos
# 93       82             115                  80           Havana
# 94        2             234                 211  Sancti Spiritus
# 95      107              92                  74           Havana
# 96       78              76                  62           Havana
# 97       19              51                  51  Sancti Spiritus
# 98      118              79                  71           Havana

# %%
# Now lets see if there are some correlation between the current price and the rest of the columns
# (rating, review, breakfast, location)
from statsmodels.formula.api import ols
from scipy.stats import pearsonr
from scipy.stats import ttest_ind
import statsmodels.api as sm

rating_corr = airbnb_table['Current_Price(USD)'].corr(airbnb_table['Rating'], method='spearman')
reviews_corr = airbnb_table['Current_Price(USD)'].corr(airbnb_table['Reviews'], method='spearman')

# ANOVA for Location
airbnb_table.rename(columns={'Current_Price(USD)': 'Current_Price'}, inplace=True)

model = ols('Current_Price ~ Location', data=airbnb_table).fit()
anova_table = sm.stats.anova_lm(model, typ=1)

# Point Biserial Correlation for breakfast
airbnb_table['Breakfast_encoded'] = airbnb_table['Breakfast'].map({'yes': 1, 'no': 0}) 
correlation, p_value = pearsonr(airbnb_table['Breakfast_encoded'], airbnb_table['Current_Price'])

# ttest for breakfast
yes_values = airbnb_table['Current_Price'][airbnb_table['Breakfast'] == 'yes']
no_values = airbnb_table['Current_Price'][airbnb_table['Breakfast'] == 'no']
t_statistic, p_value_ttest = ttest_ind(yes_values, no_values)

print(f'Rating Correlation: {rating_corr}')
print(f'Reviews Correlation: {reviews_corr}')
print('='*86)
print('ANOVA for Location:')
print(f'F: {anova_table.loc["Location", "F"]}')
print(f'pvalue: {anova_table.loc["Location","PR(>F)"]}')
print('='*86)
print('Breakfast (Point Biserial Correlation):')
print(f'Point Biserial Correlation: {correlation}')
print(f'P-value: {p_value}')
print('='*86)
print('Breakfast (ttest):')
print(f'T-test Statistic: {t_statistic}')
print(f'P-value: {p_value_ttest}')
# Out:
# Rating Correlation: 0.06895577192252746
# Reviews Correlation: 0.05213556033998342
# ======================================================================================
# ANOVA for Location:
# F: 1.5520984939311815
# pvalue: 0.15995265280315513
# ======================================================================================
# Breakfast (Point Biserial Correlation):
# Point Biserial Correlation: 0.35859819668653276
# P-value: 0.000267711848530921
# ======================================================================================
# Breakfast (ttest):
# T-test Statistic: 3.7834096147557235
# P-value: 0.00026771184853092674

# %%
# As we can see above, there is no strong correlation between the current price and the rest of the columns,
# so we cannot use them to predict a price of a house
# However, we are going to see some graphs on Tableau Public
